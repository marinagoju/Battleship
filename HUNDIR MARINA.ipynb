# %% [markdown]
# ### Cacharreo con código de Aída ###

# %%
import numpy as np

# Clase jugador
class Jugador:
    tablero = []
    tablero_impactos = []
    lenTablero = 10     # Fijo el atributo para que el tablero siempre sea 10x10
    # barcos = cnts 

    def __init__(self, maquina, nombre):
        self.maquina = maquina # BOOL
        self.nombre = nombre
        
    def initTab(self): #Crea tablero 10x10 relleno de espacios. lenTablero está fijo en 10 pero podría asignarse otro valor.  
        self.tablero = np.full((self.lenTablero, self.lenTablero), " ")
        self.tablero_impactos = np.full((self.lenTablero, self.lenTablero), " ")
        print("Generando tableros y desplegando la flota...", "\n\n", "Tablero de impactos:", "\n",self.tablero_impactos, "\n\n","Tablero de barcos:","\n", self.tablero, "\n")

        # TODO COLOCAR BARCOS en la misma funcion 

    def showTabs(self):
        print("Tablero de barcos de ", self.nombre, " \n", self.tablero)
        print("Tablero de impactos de ", self.nombre, " \n", self.tablero_impactos)

    def disparo(self):
    
        if self.maquina == False:
            x = int(input("Coordenada del eje x (abcisa):"))
            y = int(input("Coordenada del eje y (ordenada):"))

            if "|" in tablero_enemigo[x][y]:
                # tablero_enemigo.replace "|"  -> "x"
                continue
            
            elif " " in tablero_enemigo[x][y]:
                # tablero_enemigo.replace "|"  -> "o"
                # pasa turno

        elif self.maquina == True:
            x = np.random.randint(10)
            y = np.random.randint(10)
        


    
    #def recibir_disparo(self):

# %% [markdown]
# ### Cacharreo mío (Clase Game > Clase Jugador + clase barco) ###

# %%
import numpy as np

# CLASE JUGADOR
class Jugador:
    lenTablero = 10   # Fijo el atributo para que el tablero siempre sea 10x10
    tablero = np.full((lenTablero, lenTablero), " ")
    tablero_impactos = np.full((lenTablero, lenTablero), " ")
    barcos = 4 # cnt

    def __init__(self, is_pc, player_name):
        self.is_pc = is_pc # BOOL
        self.player_name = player_name

    def showTabs(self): # Muestra los tableros del jugador
        print("Tablero de barcos de ", self.player_name, " \n", self.tablero)
        print("Tablero de impactos de ", self.player_name, " \n", self.tablero_impactos)

# TODO colocar barcos

# CLASE GAME
class Game:

# atributo Turno??
    
    def __init__(self, jugador1: Jugador, jugador2: Jugador): # Tipo el argumento 
        self.jugador1 = jugador1 # usuario
        self.jugador2 = jugador2 # maquina
        

    def jugar(self):
        print("Generando tableros y desplegando la flota...")

        # llama a la funcion de iniciar tab de ambos jugadores

   
        while self.jugador1.barcos > 0: # JUGADOR

            x = int(input("Coordenada del eje x (abcisa):"))
            y = int(input("Coordenada del eje y (ordenada):"))

            if "|" in self.jugador2.tablero[x][y]:
                self.jugador2.tablero[x][y].replace("|", "x") # Da error, corregir

                if:  #  Se acierta y el barco se hunde si no hay mas "|" adjacentes", Se le quita un barco al oponente
                    print("Tocado y hundido")

                    if self.jugador2.barcos == 0: 
                        print("Victoria magistral. Todos los barcos de la flota enemiga han sido derrotados.")
                        break
                    else:
                        continue

                else:  # Se acierta y barco no se hunde
                    print("Tocado")
                    continue  
            
            else:
                coord = self.jugador2.tablero[x][y]
                coord.replace("|", "o") # Da error, corregir
                print("-Capitán Sardino: Fallamos!, arr. Más al loro grumete!", "\n\n", " Tablero de impactos: ", " \n", self.jugador1.tablero_impactos)
                # pasa turno

        while self.jugador2.barcos > 0: # MAQUINA IMPLEMENTAR MAS TARDE

            x = np.random.randint(10)
            y = np.random.randint(10)

            if "|" in self.jugador1.tablero[x][y]:
                self.jugador2.tablero[x][y].replace("|", "x") # Da error, corregir y añadir condicion de disparar a casillas adjacentes

                if self.jugador1.barcos == 0:
                    print("Derrota aplastante. Todos los barcos de tu flota se han ido a pique...")
                    break

                continue
            
            elif " " in self.jugador2.tablero[x][y]:
                coord = self.jugador2.tablero[x][y]
                coord.replace("|", "o")
                # pasa turno

# %% [markdown]
# ### Desarrollo del Programa ###

# %%
# PROGRAMA

name = input("-Capitán Sardino: Bienvenido a bordo grumete, ¿Cuál es tu nombre?:")
print(f"-Capitán Sardino: Muy bien {name}, a partir de ahora formarás parte de la flota de Caramarisal.\n\n Tu principal cometido aquí será guiarnos en el avistamiento de barcos enemigos para poder dispararles con la mayor precisión posible.\n")
print(" Antes de embarcarte en la aventura deberás tener en cuenta que:\n 'x' significa 'barco impactado'\n 'o' significa 'barco no impactado'\n\n Dicho esto, todos a sus puestos, ¡Arriad velas! !Alzad el ancla¡. La flota está a punto de zarpar...")

# TODO terminar de definir condiciones de juego para el jugador. Como rango de coords del 0 al 9. Comando salir.

maquina = Jugador(True, "maquina")
grumete = Jugador(False, name)
hundir_la_flota = Game(maquina,grumete)

hundir_la_flota.jugar()

# TODO colocar flota

# TODO terminar desarrollo del método jugar

# TODO definir un input para "salir del juego"

# TODO crear lista de constantes

# TODO crear repo en github
# Out:
# -Capitán Sardino: Muy bien Grumetito, a partir de ahora formarás parte de la flota de Caramarisal.
#
#  Tu principal cometido aquí será guiarnos en el avistamiento de barcos enemigos para poder dispararles con la mayor precisión posible.
#
#  Antes de embarcarte en la aventura deberás tener en cuenta que:
#  'x' significa 'barco impactado'
#  'o' significa 'barco no impactado'
#
#  Dicho esto, todos a sus puestos, ¡Arriad velas! !Alzad el ancla¡. La flota está a punto de zarpar.
